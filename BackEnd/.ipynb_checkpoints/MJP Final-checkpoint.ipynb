# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 800
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/My Drive/Kaggle/dataset'

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Check the contents of the current directory in your Google Drive
# !ls '/content/drive/My Drive/'

# Navigate through the directory structure to confirm the existence of 'Dataset/dataset'
# !ls '/content/drive/My Drive/Kaggle/'

# If the directory exists, use the absolute path in your code
dataset_path = '/content/drive/My Drive/Dataset/dataset'
# Out:
# '2023 latest resume'		       KAGGLE
# '2023 Navratri and arpit video '       kaggle.json
#  aggle				      'Old memories '
# 'Certificates '			      'Photo from Himanshu Singh'
# 'Colab Notebooks'		      'Photo from Himanshu Singh (1)'
# 'DATA ENGINEER ROAD MAP'	      'sanmitra book bank.pdf'
#  Dataset			      'Single photo family'
# 'DocScanner 15-Jan-2024 9-52 PM.pdf'  'Untitled folder'
# 'Gks book'			      'Voter id dad'
# 'Himanshu new update Adhaar '
# ls: cannot access '/content/drive/My Drive/Kaggle/': No such file or directory

# %%
IMAGE_SIZE = (128, 128)  # Define image size as a tuple with height and width

# Creating the dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/KAGGLE/Fruits',
    shuffle=True,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 2085 files belonging to 5 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Greening', 'Scab', 'black-spot', 'citrus-canker', 'healthy']

# %%
len(dataset)
# Out:
# 66

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
       ax = plt.subplot(3,4,i+1)
       plt.imshow(image_batch[i].numpy().astype("uint8"))
       plt.title(class_names[label_batch[i]])
       plt.axis("off")

# %%
len(dataset)
# Out:
# 66

# %%
##80% ==> training
##20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 52.800000000000004

# %%
train_ds= dataset.take(10)
len(train_ds)
# Out:
# 10

# %%
test_ds = dataset.skip(10)
len(test_ds)
# Out:
# 56

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 6.6000000000000005

# %%
val_ds= test_ds.take(7)
len(test_ds)
# Out:
# 56

# %%
test_ds = dataset.skip(3)
len(test_ds)
# Out:
# 63

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split = 0.1, shuffle=True, shuffle_size=1000):
    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)

    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 52

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
    ])

# %%
data_augmentation= tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
from tensorflow.keras import layers, models

input_shape = (128, 128, 3)  # Adjusted input shape assuming 128x128 RGB images
n_classes = 5

model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),  # Additional Conv2D layer
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),  # Additional Conv2D layer
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),  # Additional Dense layer
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1298117 (4.95 MB)
# Trainable params: 1298117 (4.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1298117 (4.95 MB)
# Trainable params: 1298117 (4.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer= 'adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    validation_data=val_ds
)
# Out:
# Epoch 1/50
# 52/52 - 227s - loss: 3.2339 - accuracy: 0.5691 - val_loss: 0.8007 - val_accuracy: 0.5365 - 227s/epoch - 4s/step
# Epoch 2/50
# 52/52 - 78s - loss: 0.6165 - accuracy: 0.7079 - val_loss: 0.5102 - val_accuracy: 0.7812 - 78s/epoch - 1s/step
# Epoch 3/50
# 52/52 - 73s - loss: 0.5098 - accuracy: 0.7548 - val_loss: 0.4681 - val_accuracy: 0.8385 - 73s/epoch - 1s/step
# Epoch 4/50
# 52/52 - 71s - loss: 0.3983 - accuracy: 0.8269 - val_loss: 0.2865 - val_accuracy: 0.9219 - 71s/epoch - 1s/step
# Epoch 5/50
# 52/52 - 72s - loss: 0.3430 - accuracy: 0.8504 - val_loss: 0.2297 - val_accuracy: 0.9635 - 72s/epoch - 1s/step
# Epoch 6/50
# 52/52 - 74s - loss: 0.2798 - accuracy: 0.8864 - val_loss: 0.3115 - val_accuracy: 0.8802 - 74s/epoch - 1s/step
# Epoch 7/50
# 52/52 - 69s - loss: 0.3080 - accuracy: 0.8798 - val_loss: 0.5597 - val_accuracy: 0.7552 - 69s/epoch - 1s/step
# Epoch 8/50
# 52/52 - 71s - loss: 0.3100 - accuracy: 0.8768 - val_loss: 0.4585 - val_accuracy: 0.7969 - 71s/epoch - 1s/step
# Epoch 9/50
# 52/52 - 74s - loss: 0.2917 - accuracy: 0.8810 - val_loss: 0.2015 - val_accuracy: 0.9375 - 74s/epoch - 1s/step
# Epoch 10/50
# 52/52 - 75s - loss: 0.1691 - accuracy: 0.9345 - val_loss: 0.1209 - val_accuracy: 0.9479 - 75s/epoch - 1s/step
# Epoch 11/50
# 52/52 - 72s - loss: 0.2018 - accuracy: 0.9231 - val_loss: 0.1327 - val_accuracy: 0.9688 - 72s/epoch - 1s/step
# Epoch 12/50
# 52/52 - 71s - loss: 0.2379 - accuracy: 0.9069 - val_loss: 0.1575 - val_accuracy: 0.9375 - 71s/epoch - 1s/step
# Epoch 13/50
# 52/52 - 71s - loss: 0.1822 - accuracy: 0.9315 - val_loss: 0.2039 - val_accuracy: 0.9219 - 71s/epoch - 1s/step
# Epoch 14/50
# 52/52 - 71s - loss: 0.1548 - accuracy: 0.9393 - val_loss: 0.1472 - val_accuracy: 0.9375 - 71s/epoch - 1s/step
# Epoch 15/50
# 52/52 - 73s - loss: 0.1100 - accuracy: 0.9597 - val_loss: 0.1519 - val_accuracy: 0.9531 - 73s/epoch - 1s/step
# Epoch 16/50
# 52/52 - 72s - loss: 0.1172 - accuracy: 0.9531 - val_loss: 0.1824 - val_accuracy: 0.9479 - 72s/epoch - 1s/step
# Epoch 17/50
# 52/52 - 75s - loss: 0.1206 - accuracy: 0.9525 - val_loss: 0.1024 - val_accuracy: 0.9740 - 75s/epoch - 1s/step
# Epoch 18/50
# 52/52 - 75s - loss: 0.0741 - accuracy: 0.9724 - val_loss: 0.1037 - val_accuracy: 0.9792 - 75s/epoch - 1s/step
# Epoch 19/50
# 52/52 - 70s - loss: 0.0625 - accuracy: 0.9784 - val_loss: 0.0676 - val_accuracy: 0.9844 - 70s/epoch - 1s/step
# Epoch 20/50
# 52/52 - 72s - loss: 0.1047 - accuracy: 0.9597 - val_loss: 0.1316 - val_accuracy: 0.9583 - 72s/epoch - 1s/step
# Epoch 21/50
# 52/52 - 71s - loss: 0.1631 - accuracy: 0.9489 - val_loss: 0.2311 - val_accuracy: 0.9219 - 71s/epoch - 1s/step
# Epoch 22/50
# 52/52 - 74s - loss: 0.1894 - accuracy: 0.9297 - val_loss: 0.1569 - val_accuracy: 0.9479 - 74s/epoch - 1s/step
# Epoch 23/50
# 52/52 - 74s - loss: 0.1066 - accuracy: 0.9561 - val_loss: 0.1001 - val_accuracy: 0.9792 - 74s/epoch - 1s/step
# Epoch 24/50
# 52/52 - 73s - loss: 0.0767 - accuracy: 0.9706 - val_loss: 0.0889 - val_accuracy: 0.9896 - 73s/epoch - 1s/step
# Epoch 25/50
# 52/52 - 71s - loss: 0.0800 - accuracy: 0.9700 - val_loss: 0.1523 - val_accuracy: 0.9635 - 71s/epoch - 1s/step
# Epoch 26/50
# 52/52 - 72s - loss: 0.0965 - accuracy: 0.9627 - val_loss: 0.3620 - val_accuracy: 0.8698 - 72s/epoch - 1s/step
# Epoch 27/50
# 52/52 - 73s - loss: 0.0747 - accuracy: 0.9694 - val_loss: 0.1187 - val_accuracy: 0.9635 - 73s/epoch - 1s/step
# Epoch 28/50
# 52/52 - 72s - loss: 0.0557 - accuracy: 0.9796 - val_loss: 0.0910 - val_accuracy: 0.9792 - 72s/epoch - 1s/step
# Epoch 29/50
# 52/52 - 68s - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.1111 - val_accuracy: 0.9792 - 68s/epoch - 1s/step
# Epoch 30/50
# 52/52 - 74s - loss: 0.0338 - accuracy: 0.9904 - val_loss: 0.1388 - val_accuracy: 0.9688 - 74s/epoch - 1s/step
# Epoch 31/50
# 52/52 - 72s - loss: 0.0379 - accuracy: 0.9868 - val_loss: 0.2196 - val_accuracy: 0.9427 - 72s/epoch - 1s/step
# Epoch 32/50
# 52/52 - 70s - loss: 0.0326 - accuracy: 0.9886 - val_loss: 0.0871 - val_accuracy: 0.9844 - 70s/epoch - 1s/step
# Epoch 33/50
# 52/52 - 75s - loss: 0.1665 - accuracy: 0.9411 - val_loss: 0.1999 - val_accuracy: 0.9375 - 75s/epoch - 1s/step
# Epoch 34/50
# 52/52 - 74s - loss: 0.0477 - accuracy: 0.9820 - val_loss: 0.0957 - val_accuracy: 0.9740 - 74s/epoch - 1s/step
# Epoch 35/50
# 52/52 - 72s - loss: 0.0402 - accuracy: 0.9832 - val_loss: 0.1726 - val_accuracy: 0.9844 - 72s/epoch - 1s/step
# Epoch 36/50
# 52/52 - 72s - loss: 0.0731 - accuracy: 0.9736 - val_loss: 0.1143 - val_accuracy: 0.9792 - 72s/epoch - 1s/step
# Epoch 37/50
# 52/52 - 71s - loss: 0.1006 - accuracy: 0.9657 - val_loss: 0.1200 - val_accuracy: 0.9740 - 71s/epoch - 1s/step
# Epoch 38/50
# 52/52 - 69s - loss: 0.1037 - accuracy: 0.9651 - val_loss: 0.1291 - val_accuracy: 0.9792 - 69s/epoch - 1s/step
# Epoch 39/50
# 52/52 - 73s - loss: 0.0823 - accuracy: 0.9730 - val_loss: 0.1296 - val_accuracy: 0.9635 - 73s/epoch - 1s/step
# Epoch 40/50
# 52/52 - 72s - loss: 0.0757 - accuracy: 0.9760 - val_loss: 0.2635 - val_accuracy: 0.9062 - 72s/epoch - 1s/step
# Epoch 41/50
# 52/52 - 71s - loss: 0.1283 - accuracy: 0.9573 - val_loss: 0.0764 - val_accuracy: 0.9844 - 71s/epoch - 1s/step
# Epoch 42/50
# 52/52 - 71s - loss: 0.0313 - accuracy: 0.9880 - val_loss: 0.0450 - val_accuracy: 0.9948 - 71s/epoch - 1s/step
# Epoch 43/50
# 52/52 - 72s - loss: 0.0540 - accuracy: 0.9796 - val_loss: 0.1025 - val_accuracy: 0.9792 - 72s/epoch - 1s/step
# Epoch 44/50
# 52/52 - 70s - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.0518 - val_accuracy: 0.9844 - 70s/epoch - 1s/step
# Epoch 45/50
# 52/52 - 74s - loss: 0.0485 - accuracy: 0.9874 - val_loss: 0.0887 - val_accuracy: 0.9740 - 74s/epoch - 1s/step
# Epoch 46/50
# 52/52 - 71s - loss: 0.0268 - accuracy: 0.9892 - val_loss: 0.0645 - val_accuracy: 0.9948 - 71s/epoch - 1s/step
# Epoch 47/50
# 52/52 - 72s - loss: 0.0562 - accuracy: 0.9814 - val_loss: 0.0693 - val_accuracy: 0.9844 - 72s/epoch - 1s/step
# Epoch 48/50
# 52/52 - 72s - loss: 0.0427 - accuracy: 0.9814 - val_loss: 0.0796 - val_accuracy: 0.9844 - 72s/epoch - 1s/step
# Epoch 49/50
# 52/52 - 72s - loss: 0.0544 - accuracy: 0.9808 - val_loss: 0.0942 - val_accuracy: 0.9792 - 72s/epoch - 1s/step
# Epoch 50/50
# 52/52 - 69s - loss: 0.0539 - accuracy: 0.9796 - val_loss: 0.1149 - val_accuracy: 0.9792 - 69s/epoch - 1s/step

# %%
# Define your RL exploration function
def explore_exploit(model, dataset, epsilon=0.1):
    for images, labels in dataset:
        batch_size = len(images)
        for i in range(batch_size):
            if np.random.rand() < epsilon:
                # Explore: Randomly choose an action (in this case, select a random image)
                rand_index = np.random.randint(0, batch_size)
                image = images[rand_index]
            else:
                # Exploit: Use the model to predict and choose the best action (image)
                predictions = model.predict(images)
                image = images[np.argmax(predictions)]

            # Train the model on the selected image
            model.train_on_batch(np.expand_dims(image, axis=0), np.array([labels[i]]))

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 18s 423ms/step - loss: 0.1480 - accuracy: 0.9688

# %%
scores

# %%
history

# %%
history.params
# Out:
# {'verbose': 2, 'epochs': 50, 'steps': 52}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history.history['accuracy']
# Out:
# [0.5691105723381042,
#  0.707932710647583,
#  0.754807710647583,
#  0.8269230723381042,
#  0.8503605723381042,
#  0.8864182829856873,
#  0.879807710647583,
#  0.8768028616905212,
#  0.8810096383094788,
#  0.934495210647583,
#  0.9230769276618958,
#  0.9068509340286255,
#  0.9314903616905212,
#  0.9393028616905212,
#  0.9597355723381042,
#  0.953125,
#  0.9525240659713745,
#  0.9723557829856873,
#  0.9783653616905212,
#  0.9597355723381042,
#  0.9489182829856873,
#  0.9296875,
#  0.956129789352417,
#  0.9705528616905212,
#  0.9699519276618958,
#  0.9627403616905212,
#  0.9693509340286255,
#  0.979567289352417,
#  0.9921875,
#  0.9903846383094788,
#  0.9867788553237915,
#  0.9885817170143127,
#  0.9411057829856873,
#  0.9819711446762085,
#  0.9831730723381042,
#  0.973557710647583,
#  0.965745210647583,
#  0.9651442170143127,
#  0.9729567170143127,
#  0.9759615659713745,
#  0.9573317170143127,
#  0.9879807829856873,
#  0.979567289352417,
#  0.9915865659713745,
#  0.987379789352417,
#  0.989182710647583,
#  0.981370210647583,
#  0.981370210647583,
#  0.9807692170143127,
#  0.979567289352417]

# %%
# Evaluate the model's performance after RL
test_accuracy = model.evaluate(test_ds)[1]  # Assuming accuracy is at index 1

print("Test Accuracy after RL:", test_accuracy)
# Out:
# 8/8 [==============================] - 3s 339ms/step - loss: 0.1480 - accuracy: 0.9688
# Test Accuracy after RL: 0.96875

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Subplot 1 (top left)
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Subplot 2 (top right)
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.tight_layout()  # Adjusts subplot parameters to fit the figure area properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'class_names' is a list of class labels

for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')  # Fix typo 'uint9' to 'uint8'
    first_label = labels_batch[0].numpy()

    print("First image to predict")
    plt.imshow(first_image)
    plt.title("First image")
    plt.show()

    print("First image's actual label:", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    predicted_label = np.argmax(batch_prediction[0])
    print("Predicted label:", class_names[predicted_label])
# Out:
# First image to predict
# First image's actual label: citrus-canker
# 1/1 [==============================] - 0s 471ms/step
# Predicted label: citrus-canker

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array,0) # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\nPredicted: {predicted_class}.\nConfidence: {confidence:.2f}%")

        plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
import matplotlib.pyplot as plt

# Example data (replace these with your actual data)
epochs = range(50)  # Assuming 50 epochs

# Example accuracy and loss values for demonstration (replace these with your actual data)
train_accuracy = [0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.92, 0.93, 0.94,
                  0.945, 0.95, 0.952, 0.955, 0.957, 0.959, 0.961, 0.963,
                  0.965, 0.966, 0.967, 0.968, 0.969, 0.97, 0.971, 0.972,
                  0.973, 0.974, 0.975, 0.976, 0.977, 0.978, 0.979, 0.98,
                  0.981, 0.982, 0.983, 0.984, 0.985, 0.986, 0.987, 0.988,
                  0.989, 0.99, 0.991, 0.992, 0.993, 0.994, 0.995, 0.996]  # Training accuracy values for each epoch (should have 50 elements)

val_accuracy = [0.4, 0.55, 0.65, 0.7, 0.72, 0.74, 0.75, 0.76, 0.77, 0.775,
                0.78, 0.782, 0.784, 0.786, 0.788, 0.79, 0.791, 0.792,
                0.793, 0.794, 0.795, 0.796, 0.797, 0.798, 0.799, 0.8,
                0.801, 0.802, 0.803, 0.804, 0.805, 0.806, 0.807, 0.808,
                0.809, 0.81, 0.811, 0.812, 0.813, 0.814, 0.815, 0.816,
                0.817, 0.818, 0.819, 0.82, 0.821, 0.822, 0.823, 0.824,
                0.825, 0.826]  # Validation accuracy values for each epoch (should have 50 elements)

train_loss = [1.2, 0.9, 0.7, 0.6, 0.55, 0.52, 0.5, 0.48, 0.45, 0.43,
              0.42, 0.41, 0.4, 0.39, 0.38, 0.37, 0.36, 0.35, 0.34,
              0.33, 0.32, 0.31, 0.3, 0.29, 0.28, 0.27, 0.26, 0.25,
              0.24, 0.23, 0.22, 0.21, 0.2, 0.19, 0.18, 0.17, 0.16,
              0.15, 0.14, 0.13, 0.12, 0.11, 0.1, 0.09, 0.08, 0.07,
              0.06, 0.05, 0.04, 0.03, 0.02, 0.01]  # Training loss values for each epoch (should have 50 elements)

val_loss = [1.5, 1.0, 0.8, 0.7, 0.65, 0.62, 0.6, 0.58, 0.55, 0.53,
            0.52, 0.51, 0.5, 0.49, 0.48, 0.47, 0.46, 0.45, 0.44,
            0.43, 0.42, 0.41, 0.4, 0.39, 0.38, 0.37, 0.36, 0.35,
            0.34, 0.33, 0.32, 0.31, 0.3, 0.29, 0.28, 0.27, 0.26,
            0.25, 0.24, 0.23, 0.22, 0.21, 0.2, 0.19, 0.18, 0.17,
            0.16]

# %%
import matplotlib.pyplot as plt
import numpy as np

for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')  # Corrected the typo in 'uint8'
    first_label = labels_batch[0].numpy()

    print("First image to predict:")
    plt.imshow(first_image)
    plt.show()
    print("First image's actual label:", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("Predicted label:", class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict:
# First image's actual label: citrus-canker
# 1/1 [==============================] - 0s 375ms/step
# Predicted label: citrus-canker

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array,0) # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
model_version=1
model.save(f"../models/{model_version}")

# %%
#string to imnteger
import os
model_version=max([int(i) for i in os.listdir("../models") + [0]]) + 1
model.save(f"../models/{model_version}")
